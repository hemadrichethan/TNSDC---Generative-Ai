# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/content/diabetes.csv.xls')

# %%
#To check wheather there is null values or not
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Pregnancies'].plot(kind='hist', bins=20, title='Pregnancies')
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame containing the data
corr = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', square=True, linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
#Classifying people who are diabetic and who are not
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the data
value_counts = df['Outcome'].value_counts()
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.title('Value Counts of Outcome')
plt.show()

# %%
#
df.pivot_table(index='Glucose', columns='BloodPressure', aggfunc='size')
# Out:
# BloodPressure  0    24   30   38   40   44   46   48   50   52   ...  96   \
# Glucose                                                          ...
# 0              NaN  NaN  NaN  NaN  NaN  NaN  NaN  1.0  NaN  NaN  ...  NaN
# 44             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 56             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 57             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 61             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 195            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 196            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 197            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 198            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 199            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
# ...

# %%
#Glucose distribution in bar chart
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Glucose Distribution')
plt.hist(df['Glucose'], bins=10, edgecolor='black')
plt.xlabel('Glucose')
plt.ylabel('Frequency')
plt.show()

# distribution in bar chart
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame containing the data
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Diabetes Pedigree Function Distribution')

# Create a bar chart
sns.histplot(data=df['DiabetesPedigreeFunction'], color='r', alpha=0.5, bins=20)

plt.xlabel('Diabetes Pedigree Function')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame containing the data
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('BMI Distribution')

# Create a bar chart
sns.histplot(data=df['BMI'], color='b', alpha=0.5, bins=20, kde=False)

plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
# Assuming 'df' is your DataFrame containing the data
feature_names = [cname for cname in df.columns if cname <= 'Age']

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Split into input (X) and output (y) variables
X = df.iloc[:, :-1].values.astype(float)
y = df.iloc[:, -1].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=7)

# Example of building a simple neural network using TensorFlow/Keras
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 18/18 [==============================] - 1s 17ms/step - loss: 6.7048 - accuracy: 0.5278 - val_loss: 5.5505 - val_accuracy: 0.5365
# Epoch 2/10
# 18/18 [==============================] - 0s 5ms/step - loss: 4.0742 - accuracy: 0.5816 - val_loss: 4.1383 - val_accuracy: 0.5938
# Epoch 3/10
# 18/18 [==============================] - 0s 5ms/step - loss: 3.1741 - accuracy: 0.6250 - val_loss: 3.4714 - val_accuracy: 0.5938
# Epoch 4/10
# 18/18 [==============================] - 0s 5ms/step - loss: 2.9243 - accuracy: 0.6285 - val_loss: 3.1687 - val_accuracy: 0.5990
# Epoch 5/10
# 18/18 [==============================] - 0s 6ms/step - loss: 2.7550 - accuracy: 0.6215 - val_loss: 2.9012 - val_accuracy: 0.5625
# Epoch 6/10
# 18/18 [==============================] - 0s 5ms/step - loss: 2.5103 - accuracy: 0.6181 - val_loss: 2.6132 - val_accuracy: 0.5885
# Epoch 7/10
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the Keras model
model = Sequential([
    Dense(12, input_dim=8, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)


# fFit the Model and doing Predictions
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/10
# 18/18 [==============================] - 1s 13ms/step - loss: 18.6507 - accuracy: 0.3646 - val_loss: 16.6032 - val_accuracy: 0.3802
# Epoch 2/10
# 18/18 [==============================] - 0s 4ms/step - loss: 13.8555 - accuracy: 0.3889 - val_loss: 12.2047 - val_accuracy: 0.4010
# Epoch 3/10
# 18/18 [==============================] - 0s 4ms/step - loss: 10.0469 - accuracy: 0.4149 - val_loss: 8.5714 - val_accuracy: 0.3802
# Epoch 4/10
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7298 - accuracy: 0.4253 - val_loss: 5.2542 - val_accuracy: 0.3802
# Epoch 5/10
# 18/18 [==============================] - 0s 5ms/step - loss: 3.7580 - accuracy: 0.4514 - val_loss: 2.5457 - val_accuracy: 0.4948
# Epoch 6/10
# 18/18 [==============================] - 0s 4ms/step - loss: 1.8431 - accuracy: 0.5573 - val_loss: 1.4464 - val_accuracy: 0.6250
# Epoch 7/10
# ...

# %%
#Import Necessary Libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_val shape: {X_val.shape}')
print(f'y_val shape: {y_val.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')

print(model.layers[0].input_shape)
# Out:
# X_train shape: (8, 8, 1, 1)
# y_train shape: (8,)
# X_val shape: (38, 8)
# y_val shape: (38,)
# X_test shape: (3, 8, 1, 1)
# y_test shape: (3,)
# (None, 64, 64, 3)

# %%
# Assuming X_train is your array
original_size = X_train.size
print("Original Size:", original_size)
# Assuming X_train is your array
original_shape = X_train.shape
print("Original Shape:", original_shape)

print(X.shape)
# Out:
# Original Size: 64
# Original Shape: (8, 8, 1, 1)
# (11, 8, 1, 1)
